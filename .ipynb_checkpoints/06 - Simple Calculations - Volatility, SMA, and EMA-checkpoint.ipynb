# %% [markdown]
# <a
#  href="https://colab.research.google.com/github/LearnPythonWithRune/FinancialDataAnalysisWithPython/blob/main/colab/starter/06 - Simple Calculations - Volatility, SMA, and EMA.ipynb"
#  target="_parent">
# <img
#  src="https://colab.research.google.com/assets/colab-badge.svg"
# alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 6. Calculating Financial parameters using NumPy
#
# - [Pct change](https://www.investopedia.com/terms/p/percentage-change.asp)：represents the degree of change over time.
# Increase = New Number - Original Number
# % increase = Increase ÷ Original Number × 100.
# - Log returns
# - Standard deviation (Volatility)
# - Rolling
#     - Simple Moving Avarage
#     - Exponential Moving Average

# %% [markdown]
# ### Standard deviation
#
# - $\sigma_{p} = \sigma_{daily}\times \sqrt{p}$
# - $\sigma_{annually} = \sigma_{daily}\times \sqrt{252}$
#
#     *(252 trading days per year)*

# %%
# load data 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
data = pd.read_csv("AAPL.csv", index_col=0, parse_dates=True)

# %%
# import numpy and create a new column called Log returns
import numpy as np

# %% [markdown]
# ## Calculate Log Return (LR) and add into DataFrame

# %%
data['Log returns'] = np.log(data['Close']/data['Close'].shift())

# %%
# check data
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
#
#             Log returns
# Date
# 2020-01-27          NaN
# 2020-01-28     0.027897
# 2020-01-29     0.020716
# 2020-01-30    -0.001450
# 2020-01-31    -0.045352

# %% [markdown]
# ## Calculate market volatility

# %% [markdown]
# The market volatility is the variation (Change of the return). It is normally calculated by the standard deviation.
#
# This can be calculated from our Log returns as follows.

# %%
data['Log returns'].std()
# Out:
# 0.029763804543855122

# %% [markdown]
# The volatility is generally defined as the **annualized standard deviation**. Using the above formula we can calculate it as follows.

# %%
volatility = data['Log returns'].std()*252**.5

# %%
print("volatility:", volatility)
# Out:
# volatility: 0.47248574936504945

# %% [markdown]
# We can visualize Apple (AAPL ticket number) stock volatility

# %%
str_vol = str(round(volatility, 4)*100)
fig, ax = plt.subplots()
data['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("AAPL volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Text(0.5, 1.0, 'AAPL volatility: 47.25%')

# %% [markdown]
# ## Understand price trend in the market

# %% [markdown]
# The simple moving average (SMA) and The exponential moving average (EMA) are used to  Measure market price trend direction over a period of time

# %%
# calculate Apple's stocke price 10 day SMA and add into DataFrame
data['SMA10'] = data['Close'].rolling(10).mean()

# %%
# calculate Apple's stocke price 10 day EMA and add into DataFrame
data['EMA10'] = data['Close'].ewm(span=10, adjust=False).mean()

# %%
data.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
# 2020-02-03  76.074997  78.372498  75.555000  77.165001  76.504311  173985600
# 2020-02-04  78.827499  79.910004  78.407501  79.712502  79.029999  136616400
# 2020-02-05  80.879997  81.190002  79.737503  80.362503  79.674438  118826800
# 2020-02-06  80.642502  81.305000  80.065002  81.302498  80.606384  105425600
# 2020-02-07  80.592499  80.849998  79.500000  80.007500  79.510727  117684000
# 2020-02-10  78.544998  80.387497  78.462502  80.387497  79.888359  109348800
# 2020-02-11  80.900002  80.974998  79.677498  79.902496  79.406372   94323200
# 2020-02-12  80.367500  81.805000  80.367500  81.800003  81.292099  113730400
# 2020-02-13  81.047501  81.555000  80.837502  81.217499  80.713219   94747600
# 2020-02-14  81.184998  81.495003  80.712502  81.237503  80.733086   80113600
# 2020-02-18  78.839996  79.937500  78.652496  79.750000  79.254822  152531200
# 2020-02-19  80.000000  81.142502  80.000000  80.904999  80.402649   93984000
# 2020-02-20  80.657501  81.162498  79.552498  80.074997  79.577805  100566000
# 2020-02-21  79.654999  80.112503  77.625000  78.262497  77.776558  129554000
# 2020-02-24  74.315002  76.044998  72.307503  74.544998  74.082146  222195200
#
#                 SMA10      EMA10
# Date
# 2020-01-27        NaN  77.237503
# 2020-01-28        NaN  77.634775
# 2020-01-29        NaN  78.262089
# 2020-01-30        NaN  78.753982
# 2020-01-31        NaN  78.503713
# 2020-02-03        NaN  78.260310
# 2020-02-04        NaN  78.524345
# 2020-02-05        NaN  78.858556
# 2020-02-06        NaN  79.302909
# 2020-02-07  79.464001  79.431016
# 2020-02-10  79.779000  79.604922
# 2020-02-11  79.827000  79.659026
# 2020-02-12  79.898500  80.048295
# 2020-02-13  79.923500  80.260877
# 2020-02-14  80.309500  80.438446
# 2020-02-18  80.568000  80.313274
# 2020-02-19  80.687250  80.420860
# 2020-02-20  80.658499  80.357976
# 2020-02-21  80.354499  79.976980
# 2020-02-24  79.808249  78.989347

# %% [markdown]
# ## Visualize market volatility

# %%
# Visualise bothe moving average
fig, ax = plt.subplots()
data[['SMA10', 'EMA10']].loc['2020-12-01':].plot(ax=ax)
data['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Qestion: What is the freen line indicates?

# %% [markdown]
# # End
